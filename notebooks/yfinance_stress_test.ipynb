# %% [markdown]
# # YFinance Throughput & Soft Rate-Limit Analysis
# This notebook measures:
# - response latency
# - throughput
# - throttling signals
# without performing abusive load.

# %%
import time
import yfinance as yf
import numpy as np
from datetime import datetime
import pandas as pd

results = []

# %%
ticker = "MDLZ"
num_requests = 150          # enough to measure pattern
initial_sleep = 0.5         # 2 requests/sec
min_sleep = 0.05            # approach 20 req/sec gradually
sleep_decay = 0.97          # shrink sleep slightly each iteration

# %%
sleep_time = initial_sleep

for i in range(num_requests):

    t0 = time.time()
    try:
        df = yf.download(ticker, period="1d", interval="1m", progress=False)
        success = not df.empty
    except Exception as e:
        success = False

    latency = time.time() - t0

    results.append({
        "i": i,
        "success": success,
        "latency": latency,
        "sleep": sleep_time,
        "timestamp": datetime.now()
    })

    print(f"[{i}] success={success} latency={latency:.3f}s sleep={sleep_time:.3f}s")

    # detect throttling
    if not success:
        print("⚠️ Soft limit detected — stopping test safely.")
        break

    # gradually reduce sleep (increase RPS)
    sleep_time = max(min_sleep, sleep_time * sleep_decay)
    time.sleep(sleep_time)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [0] success=True latency=1.040s sleep=0.500s
# [1] success=True latency=0.328s sleep=0.485s
# [2] success=True latency=0.265s sleep=0.470s
# [3] success=True latency=0.186s sleep=0.456s
# [4] success=True latency=0.194s sleep=0.443s
# [5] success=True latency=0.152s sleep=0.429s
# [6] success=True latency=0.256s sleep=0.416s
# [7] success=True latency=0.272s sleep=0.404s
# [8] success=True latency=0.205s sleep=0.392s
# [9] success=True latency=0.197s sleep=0.380s
# [10] success=True latency=0.257s sleep=0.369s
# [11] success=True latency=0.237s sleep=0.358s
# [12] success=True latency=0.370s sleep=0.347s
# [13] success=True latency=0.178s sleep=0.337s
# [14] success=True latency=0.264s sleep=0.326s
# [15] success=True latency=0.257s sleep=0.317s
# [16] success=True latency=0.160s sleep=0.307s
# [17] success=True latency=0.230s sleep=0.298s
# [18] success=True latency=0.277s sleep=0.289s
# [19] success=True latency=0.171s sleep=0.280s
# [20] success=True latency=0.240s sleep=0.272s
# [21] success=True latency=0.248s sleep=0.264s
# [22] success=True latency=0.212s sleep=0.256s
# [23] success=True latency=0.286s sleep=0.248s
# [24] success=True latency=0.185s sleep=0.241s
# [25] success=True latency=0.253s sleep=0.233s
# [26] success=True latency=0.284s sleep=0.226s
# [27] success=True latency=0.191s sleep=0.220s
# [28] success=True latency=0.323s sleep=0.213s
# [29] success=True latency=0.252s sleep=0.207s
# [30] success=True latency=0.196s sleep=0.201s
# [31] success=True latency=0.279s sleep=0.194s
# [32] success=True latency=0.201s sleep=0.189s
# [33] success=True latency=0.227s sleep=0.183s
# [34] success=True latency=0.324s sleep=0.178s
# [35] success=True latency=0.237s sleep=0.172s
# [36] success=True latency=0.137s sleep=0.167s
# [37] success=True latency=0.287s sleep=0.162s
# [38] success=True latency=0.229s sleep=0.157s
# [39] success=True latency=0.261s sleep=0.152s
# [40] success=True latency=0.212s sleep=0.148s
# [41] success=True latency=0.282s sleep=0.143s
# [42] success=True latency=0.204s sleep=0.139s
# [43] success=True latency=0.250s sleep=0.135s
# [44] success=True latency=0.233s sleep=0.131s
# [45] success=True latency=0.384s sleep=0.127s
# [46] success=True latency=0.210s sleep=0.123s
# [47] success=True latency=0.188s sleep=0.119s
# [48] success=True latency=0.195s sleep=0.116s
# [49] success=True latency=0.264s sleep=0.112s
# [50] success=True latency=0.239s sleep=0.109s
# [51] success=True latency=0.217s sleep=0.106s
# [52] success=True latency=0.209s sleep=0.103s
# [53] success=True latency=0.187s sleep=0.100s
# [54] success=True latency=0.295s sleep=0.097s
# [55] success=True latency=0.261s sleep=0.094s
# [56] success=True latency=0.206s sleep=0.091s
# [57] success=True latency=0.219s sleep=0.088s
# [58] success=True latency=0.222s sleep=0.085s
# [59] success=True latency=0.406s sleep=0.083s
# [60] success=True latency=0.209s sleep=0.080s
# [61] success=True latency=0.270s sleep=0.078s
# [62] success=True latency=0.224s sleep=0.076s
# [63] success=True latency=0.230s sleep=0.073s
# [64] success=True latency=0.256s sleep=0.071s
# [65] success=True latency=0.182s sleep=0.069s
# [66] success=True latency=0.201s sleep=0.067s
# [67] success=True latency=0.285s sleep=0.065s
# [68] success=True latency=0.381s sleep=0.063s
# [69] success=True latency=0.229s sleep=0.061s
# [70] success=True latency=0.180s sleep=0.059s
# [71] success=True latency=0.219s sleep=0.058s
# [72] success=True latency=0.265s sleep=0.056s
# [73] success=True latency=0.306s sleep=0.054s
# [74] success=True latency=0.287s sleep=0.052s
# [75] success=True latency=0.251s sleep=0.051s
# [76] success=True latency=0.398s sleep=0.050s
# [77] success=True latency=0.266s sleep=0.050s
# [78] success=True latency=0.288s sleep=0.050s
# [79] success=True latency=0.151s sleep=0.050s
# [80] success=True latency=0.297s sleep=0.050s
# [81] success=True latency=0.417s sleep=0.050s
# [82] success=True latency=0.244s sleep=0.050s
# [83] success=True latency=0.211s sleep=0.050s
# [84] success=True latency=0.208s sleep=0.050s
# [85] success=True latency=0.224s sleep=0.050s
# [86] success=True latency=0.242s sleep=0.050s
# [87] success=True latency=0.218s sleep=0.050s
# [88] success=True latency=0.326s sleep=0.050s
# [89] success=True latency=0.207s sleep=0.050s
# [90] success=True latency=0.223s sleep=0.050s
# [91] success=True latency=0.272s sleep=0.050s
# [92] success=True latency=0.289s sleep=0.050s
# [93] success=True latency=0.190s sleep=0.050s
# [94] success=True latency=0.301s sleep=0.050s
# [95] success=True latency=0.487s sleep=0.050s
# [96] success=True latency=0.229s sleep=0.050s
# [97] success=True latency=0.207s sleep=0.050s
# [98] success=True latency=0.188s sleep=0.050s
# [99] success=True latency=0.176s sleep=0.050s
# [100] success=True latency=0.232s sleep=0.050s
# [101] success=True latency=0.322s sleep=0.050s
# [102] success=True latency=0.312s sleep=0.050s
# [103] success=True latency=0.293s sleep=0.050s
# [104] success=True latency=0.227s sleep=0.050s
# [105] success=True latency=0.259s sleep=0.050s
# [106] success=True latency=0.173s sleep=0.050s
# [107] success=True latency=0.213s sleep=0.050s
# [108] success=True latency=0.218s sleep=0.050s
# [109] success=True latency=0.248s sleep=0.050s
# [110] success=True latency=0.332s sleep=0.050s
# [111] success=True latency=0.264s sleep=0.050s
# [112] success=True latency=0.376s sleep=0.050s
# [113] success=True latency=0.225s sleep=0.050s
# [114] success=True latency=0.230s sleep=0.050s
# [115] success=True latency=0.308s sleep=0.050s
# [116] success=True latency=0.191s sleep=0.050s
# [117] success=True latency=0.194s sleep=0.050s
# [118] success=True latency=0.252s sleep=0.050s
# [119] success=True latency=0.158s sleep=0.050s
# [120] success=True latency=0.155s sleep=0.050s
# [121] success=True latency=0.166s sleep=0.050s
# [122] success=True latency=0.250s sleep=0.050s
# [123] success=True latency=0.276s sleep=0.050s
# [124] success=True latency=0.229s sleep=0.050s
# [125] success=True latency=0.254s sleep=0.050s
# [126] success=True latency=0.223s sleep=0.050s
# [127] success=True latency=0.379s sleep=0.050s
# [128] success=True latency=0.187s sleep=0.050s
# [129] success=True latency=0.251s sleep=0.050s
# [130] success=True latency=0.231s sleep=0.050s
# [131] success=True latency=0.275s sleep=0.050s
# [132] success=True latency=0.249s sleep=0.050s
# [133] success=True latency=0.271s sleep=0.050s
# [134] success=True latency=0.334s sleep=0.050s
# [135] success=True latency=0.279s sleep=0.050s
# [136] success=True latency=0.216s sleep=0.050s
# [137] success=True latency=0.172s sleep=0.050s
# [138] success=True latency=0.267s sleep=0.050s
# [139] success=True latency=0.258s sleep=0.050s
# [140] success=True latency=0.249s sleep=0.050s
# [141] success=True latency=0.212s sleep=0.050s
# [142] success=True latency=0.192s sleep=0.050s
# [143] success=True latency=0.234s sleep=0.050s
# [144] success=True latency=0.193s sleep=0.050s
# [145] success=True latency=0.147s sleep=0.050s
# [146] success=True latency=0.245s sleep=0.050s
# [147] success=True latency=0.277s sleep=0.050s
# [148] success=True latency=0.210s sleep=0.050s
# [149] success=True latency=0.191s sleep=0.050s

# %%
df = pd.DataFrame(results)
df.tail()
# Out:
#        i  success   latency  sleep                  timestamp
# 145  145     True  0.146508   0.05 2025-12-02 00:07:22.926401
# 146  146     True  0.245162   0.05 2025-12-02 00:07:23.242427
# 147  147     True  0.276607   0.05 2025-12-02 00:07:23.569501
# 148  148     True  0.209660   0.05 2025-12-02 00:07:23.830105
# 149  149     True  0.190605   0.05 2025-12-02 00:07:24.071339

# %%
print("Average latency:", df['latency'].mean())
print("Min latency:", df['latency'].min())
print("Max latency:", df['latency'].max())

# where failures start
failures = df[~df['success']]
if len(failures) > 0:
    print("Soft throttle triggered at request:", failures.iloc[0]['i'])
    print("Sleep time at trigger:", failures.iloc[0]['sleep'])
else:
    print("No throttle encountered.")
# Out:
# Average latency: 0.250387765566508
# Min latency: 0.13726353645324707
# Max latency: 1.0399448871612549
# No throttle encountered.
